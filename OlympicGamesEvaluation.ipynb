# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
dataFrame1 = pd.read_csv("Medals_Standing.csv")
dataFrame1.head(10)
# Out:
#                           NOC  Gold  Silver  Bronze  Total
# 0                      Norway    16       8      13     37
# 1                     Germany    12      10       5     27
# 2  People's Republic of China     9       4       2     15
# 3    United States of America     8      10       7     25
# 4                      Sweden     8       5       5     18
# 5                 Netherlands     8       5       4     17
# 6                     Austria     7       7       4     18
# 7                 Switzerland     7       2       5     14
# 8                         ROC     6      12      14     32
# 9                      France     5       7       2     14

# %%
dataFrame1.shape
#numero de rows e numero de columns
# Out:
# (29, 5)

# %%
dataFrame1.columns
# Out:
# Index(['NOC', 'Gold', 'Silver', 'Bronze', 'Total'], dtype='object')

# %%
dataFrame1[dataFrame1.columns[0]].count()
# Out:
# 29

# %%
dataFrame1['NOC'].tail(20)
#mostra os vinte ultimos valores da variável que está sendo chamada
# Out:
# 9                France
# 10               Canada
# 11                Japan
# 12                Italy
# 13    Republic of Korea
# 14             Slovenia
# 15              Finland
# 16          New Zealand
# 17            Australia
# 18        Great Britain
# 19              Hungary
# 20              Belgium
# 21       Czech Republic
# 22             Slovakia
# 23              Belarus
# 24                Spain
# 25              Ukraine
# 26              Estonia
# 27               Latvia
# 28               Poland
# Name: NOC, dtype: object

# %%
dataFrame1.max()
# Out:
# NOC       United States of America
# Gold                            16
# Silver                          12
# Bronze                          14
# Total                           37
# dtype: object

# %%
plt.rcParams.update({'font.size':20})

# %%
dataFrame2 = dataFrame1.drop(['Silver', 'Bronze', 'Total'], axis='columns')

# %%
dataFrame2.shape
# Out:
# (29, 2)

# %%
dataFrame2.columns
# Out:
# Index(['NOC', 'Gold'], dtype='object')

# %%
dataFrame2
# Out:
#                            NOC  Gold
# 0                       Norway    16
# 1                      Germany    12
# 2   People's Republic of China     9
# 3     United States of America     8
# 4                       Sweden     8
# 5                  Netherlands     8
# 6                      Austria     7
# 7                  Switzerland     7
# 8                          ROC     6
# 9                       France     5
# 10                      Canada     4
# 11                       Japan     3
# 12                       Italy     2
# 13           Republic of Korea     2
# 14                    Slovenia     2
# 15                     Finland     2
# 16                 New Zealand     2
# 17                   Australia     1
# 18               Great Britain     1
# 19                     Hungary     1
# 20                     Belgium     1
# 21              Czech Republic     1
# 22                    Slovakia     1
# 23                     Belarus     0
# ...

# %%
dataFrame2.loc[:,['Gold']]
# Out:
#     Gold
# 0     16
# 1     12
# 2      9
# 3      8
# 4      8
# 5      8
# 6      7
# 7      7
# 8      6
# 9      5
# 10     4
# 11     3
# 12     2
# 13     2
# 14     2
# 15     2
# 16     2
# 17     1
# 18     1
# 19     1
# 20     1
# 21     1
# 22     1
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     0

# %%
dataFigure = dataFrame2.plot(figsize=(10,6), kind='bar', color = '#ffff42')
dataFigure.set_xticklabels(dataFrame2['NOC'])
plt.rcParams.update({'font.size':14})
plt.savefig('goldMedalWinners.jpg', format='jpg', transparent=True, dpi=300, bbox_inches='tight')

# %%
dataFrame3 = dataFrame1.drop(['Gold', 'Bronze', 'Total'], axis='columns')
dataFrame3
# Out:
#                            NOC  Silver
# 0                       Norway       8
# 1                      Germany      10
# 2   People's Republic of China       4
# 3     United States of America      10
# 4                       Sweden       5
# 5                  Netherlands       5
# 6                      Austria       7
# 7                  Switzerland       2
# 8                          ROC      12
# 9                       France       7
# 10                      Canada       8
# 11                       Japan       6
# 12                       Italy       7
# 13           Republic of Korea       5
# 14                    Slovenia       3
# 15                     Finland       2
# 16                 New Zealand       1
# 17                   Australia       2
# 18               Great Britain       1
# 19                     Hungary       0
# 20                     Belgium       0
# 21              Czech Republic       0
# 22                    Slovakia       0
# ...

# %%
dataFigure2 = dataFrame3.plot(figsize=(10,6), kind='bar', color = '#dde1dc')
dataFigure2.set_xticklabels(dataFrame3['NOC'])
plt.savefig('silverMedalWinners.jpg', format='jpg', transparent=True, dpi=300, bbox_inches='tight')

# %%
dataFrame4 = dataFrame1.drop(['Gold', 'Silver', 'Total'], axis='columns')
dataFrame4
# Out:
#                            NOC  Bronze
# 0                       Norway      13
# 1                      Germany       5
# 2   People's Republic of China       2
# 3     United States of America       7
# 4                       Sweden       5
# 5                  Netherlands       4
# 6                      Austria       4
# 7                  Switzerland       5
# 8                          ROC      14
# 9                       France       2
# 10                      Canada      14
# 11                       Japan       9
# 12                       Italy       8
# 13           Republic of Korea       2
# 14                    Slovenia       2
# 15                     Finland       4
# 16                 New Zealand       0
# 17                   Australia       1
# 18               Great Britain       0
# 19                     Hungary       2
# 20                     Belgium       1
# 21              Czech Republic       1
# 22                    Slovakia       1
# ...

# %%
dataFigure3 = dataFrame4.plot(figsize=(10,6), kind='bar', color = '#d18c00')
dataFigure3.set_xticklabels(dataFrame3['NOC'])
plt.savefig('bronzeMedalWinners.jpg', format='jpg', transparent=True, dpi=300, bbox_inches='tight')

# %%
dataFrame4.value_counts()
# Out:
# NOC                         Bronze
# Australia                   1         1
# Netherlands                 4         1
# Ukraine                     0         1
# Switzerland                 5         1
# Sweden                      5         1
# Spain                       0         1
# Slovenia                    2         1
# Slovakia                    1         1
# Republic of Korea           2         1
# ROC                         14        1
# Poland                      1         1
# People's Republic of China  2         1
# Norway                      13        1
# New Zealand                 0         1
# Latvia                      1         1
# Austria                     4         1
# Japan                       9         1
# Italy                       8         1
# Hungary                     2         1
# Great Britain               0         1
# Germany                     5         1
# France                      2         1
# ...

# %%
bronzeOrdenado = dataFrame4.sort_values(['Bronze'], ascending=False)
bronzeOrdenado
# Out:
#                            NOC  Bronze
# 8                          ROC      14
# 10                      Canada      14
# 0                       Norway      13
# 11                       Japan       9
# 12                       Italy       8
# 3     United States of America       7
# 1                      Germany       5
# 4                       Sweden       5
# 7                  Switzerland       5
# 5                  Netherlands       4
# 6                      Austria       4
# 15                     Finland       4
# 19                     Hungary       2
# 14                    Slovenia       2
# 13           Republic of Korea       2
# 9                       France       2
# 2   People's Republic of China       2
# 17                   Australia       1
# 20                     Belgium       1
# 21              Czech Republic       1
# 22                    Slovakia       1
# 26                     Estonia       1
# 27                      Latvia       1
# ...

# %%
dataFrame1.sort_values(['Total'], ascending=False)
# Out:
#                            NOC  Gold  Silver  Bronze  Total
# 0                       Norway    16       8      13     37
# 8                          ROC     6      12      14     32
# 1                      Germany    12      10       5     27
# 10                      Canada     4       8      14     26
# 3     United States of America     8      10       7     25
# 4                       Sweden     8       5       5     18
# 6                      Austria     7       7       4     18
# 11                       Japan     3       6       9     18
# 5                  Netherlands     8       5       4     17
# 12                       Italy     2       7       8     17
# 2   People's Republic of China     9       4       2     15
# 7                  Switzerland     7       2       5     14
# 9                       France     5       7       2     14
# 13           Republic of Korea     2       5       2      9
# 15                     Finland     2       2       4      8
# ...

# %%
labels = dataFrame1['NOC']
valores = dataFrame1['Total']
plt.figure(figsize=(7,7))
plt.pie(x=valores, labels=labels, autopct='%1.1f%%')
plt.show()
plt.savefig('medalWinners.jpg', format='jpg', transparent=True, dpi=300, bbox_inches='tight')

# %%
display(dataFrame1.dtypes)
# Out:
# NOC       object
# Gold       int64
# Silver     int64
# Bronze     int64
# Total      int64
# dtype: object
